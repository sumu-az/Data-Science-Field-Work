# %% [markdown]
# # Python Basics: Variables and Data Types

# %% [markdown]
# # Assignment 1: Create two variables, one holding a number and the other holding your name. Then print both.

# %%
age = 24
name = "Sumaiya Binte Azad"

print("Age: ", age, end="; ")
print("Name: ", name)
# Out:
# Age:  24; Name:  Sumaiya Binte Azad

# %% [markdown]
# # Assignment 2: Create variables of different types and use the type() function to check their types.

# %%
a = 54            # int
b = 2.01254       # float
c = "Variables"   # str
d = False         # bool

print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# # Assignment 3: Fix the bad variable name above and create three more variables with good naming practices.

# %%
bad_name = 23
bad2 = 42.78
student_name = "Sumaiya"
present = True

print(bad_name)
print(bad2)
print(student_name)
print(present)
# Out:
# 23
# 42.78
# Sumaiya
# True

# %% [markdown]
# # Assignment 4: Create a variable, assign it a value of one type, then reassign it to a different type and print both.

# %%
var2 = "My Name is Sumaiya"
print(var2)

var2 = 54
print(var2)
# Out:
# My Name is Sumaiya
# 54
